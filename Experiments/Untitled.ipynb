# %%
# %matplotlib notebook

import numpy as np
from matplotlib import pyplot as plt

import pandas as pd
import xarray as xr

import qcodes as qc
from qcodes.dataset.data_set import DataSet, new_data_set

from plottr.data.datadict import DataDict
from plottr.data.qcodes import DataSetDict

from pytopo.mplplots.init_nb_plotting import *

qc.config['core']['db_location'] = r"d:/OneDrive/BF1/Data/experiments.db"

# %%
run_id = 229

data = DataSetDict(run_id=run_id)
data.structure()
# Out:
# {'ivvi_setup_v_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': 'V'},
#  'ivvi_setup_dac5': {'axes': [], 'unit': 'V'},
#  'ivvi_setup_i1_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': 'A'},
#  'ivvi_setup_i2_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': 'A'},
#  'ivvi_setup_i3_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': 'A'},
#  'ivvi_setup_g1_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': '2e2/h'},
#  'ivvi_setup_g2_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': '2e2/h'},
#  'ivvi_setup_g3_measurement': {'axes': ['ivvi_setup_dac5'], 'unit': '2e2/h'}}

# %%
# data.get_grid('ivvi_setup_v_measurement')

# %%
data['ivvi_setup_g3_measurement']
# Out:
# {'values': array([  1.15806521e-05,  -8.88046879e-06,   5.33718131e-05,
#          -3.61056695e-05,   4.64866069e-05,  -2.88168542e-05,
#           3.59797238e-05,  -2.61087732e-05,   6.64157376e-05,
#          -3.90506962e-05,  -5.10234158e-05,  -1.30853863e-05,
#           6.23845212e-05,  -1.75718512e-05,   5.28084896e-05,
#          -2.72640977e-05,  -4.83881423e-05,  -1.18260683e-05,
#          -1.11894932e-05,   5.02441839e-06,  -2.61160506e-05,
#           7.17954546e-05,  -3.81208657e-05,   4.56577176e-05,
#          -3.40546931e-06,   2.46282847e-05,  -4.94120516e-05,
#           9.03166139e-06,  -3.06655334e-05,   5.37325700e-05,
#           5.33630212e-05,   3.42440241e-05,  -1.81387860e-05,
#          -1.48606910e-06,   1.61322079e-05,  -4.93804832e-05,
#           5.56718618e-05,  -4.07372952e-05,   5.93043285e-05,
#          -3.14578123e-05,   7.11589790e-05,   5.15552641e-05,
#          -2.72236610e-05,   9.94505531e-06,  -4.79504639e-06,
#          -4.27817029e-06,  -3.33031398e-06,   5.91458796e-05,
#          -1.47742432e-05,   1.62826953e-05,  -4.59763950e-05,
#           6.76521508e-05,  -3.49698755e-05,   5.35537439e-05,
#          -3.64674678e-05,   4.01952708e-05,  -4.41022875e-05,
#           5.20741111e-05,  -3.74707626e-05,   2.50871877e-05,
#          -4.51150129e-05,  -9.07186535e-06,   3.01707839e-06,
#          -1.76495396e-05,   1.20258628e-05,  -2.49283056e-05,
#           3.60278032e-05,  -2.38454740e-05,   6.28276706e-05,
#          -2.57829349e-05,   5.15650831e-05,  -5.19792016e-05,
#           6.10025271e-05,  -3.74609029e-05,   4.84807506e-05,
#          -2.99351211e-05,   4.33069765e-05,  -3.78037210e-05,
#           3.12839497e-05,   1.27301769e-05,   2.93342066e-05,
#           8.08297541e-06,  -9.99795893e-06,   2.05725085e-05,
#          -1.25498842e-05,   4.16437130e-05,  -3.50070430e-05,
#           2.66799982e-05,  -5.20907210e-05,   1.90483524e-05,
#          -2.20840889e-05,   6.56957220e-05,  -4.00918264e-05,
#           3.97301669e-05,  -2.31357077e-05,   5.99238506e-05,
#           7.73726617e-06,   6.99972494e-06,   5.30602981e-05,
#          -6.95365218e-06,   3.84921410e-05]),
#  'unit': '2e2/h',
#  'axes': ['ivvi_setup_dac5']}

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x) + np.random.random(100) * 0.8

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

plt.plot(x, y,'o')
plt.plot(x, smooth(y,3), 'r-', lw=2)
plt.plot(x, smooth(y,19), 'g-', lw=2)
# Out:
# <img src="data:image/png;base64,..." width="675">
